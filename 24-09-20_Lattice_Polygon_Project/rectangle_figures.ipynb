# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from plotting_functions import plot_squares, plot_polygons

# %%
size_range = range(1,16)

# %%
shape_column_names = ["dimension", "boundary", "interior", "area"]
squares_formula_dictionary = {"dimension": lambda n: n, 
                              "boundary": lambda n: 4*n, 
                              "interior": lambda n: (n-1)**2, 
                              "area": lambda n: n**2
                              }
squares_dataframe_content = {column_name:[squares_formula_dictionary[column_name](n) for n in size_range] 
                             for column_name in shape_column_names}
squares = pd.DataFrame(squares_dataframe_content, index=size_range)

# %%
# from plotting_functions import draw_polygon
# vertices = (1,2), (3,4), (0,3)
# polygon = Polygon(vertices, closed=True) #, edgecolor='green', facecolor='blue'

# %%
plot_polygons(13, , vertex_rule = lambda n: [(0,0), (n,0), (0,n)])

# %%
# squares["area_formula"] = 1/2*squares.boundary + squares.interior - 1
squares
# Out:
#     dimension  boundary  interior  area
# 1           1         4         0     1
# 2           2         8         1     4
# 3           3        12         4     9
# 4           4        16         9    16
# 5           5        20        16    25
# 6           6        24        25    36
# 7           7        28        36    49
# 8           8        32        49    64
# 9           9        36        64    81
# 10         10        40        81   100
# 11         11        44       100   121
# 12         12        48       121   144
# 13         13        52       144   169
# 14         14        56       169   196
# 15         15        60       196   225
